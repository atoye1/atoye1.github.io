# %% [markdown]
# <a href="https://colab.research.google.com/github/atoye1/atoye1.github.io/blob/main/_posts/%EC%95%8C%EA%B3%A0%EB%A6%AC%EC%A6%98%EC%9D%98_%EC%A4%91%EC%9A%94_%ED%8F%AC%EC%9D%B8%ED%8A%B8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def sum_n(n):
    s = 0
    for i in range(1, n+1):
        s += i
    return s

# %%
sum_n(10000)
# Out:
# 50005000

# %%
def sum_n_gauss(n):
    return (n+1)*n//2

# %%
sum_n_gauss(10)]]
# Out:
# 55.0

# %% [markdown]
# sum_n 과 sum_n_gauss 는 동일한 기능을 수행하는 함수이지만, 시간복잡도의 차이로 sum_n_gauss함수가 더 우수한 알고리즘
